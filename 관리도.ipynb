# %%
# 라이브러리 호출하기
import pandas as pd # 데이터 불러오거나 집계하거나 시각화 활용
import numpy as np # 수학 연산에 활용
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import seaborn as sns # 데이터 시각화(그래프)
from scipy import stats # 통계분석에 활용

#그래프 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic' # 한글 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False # 마이너스 깨짐 방지

# %%
import os # 운영체제(operating system) 관련 패키지 호출

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user'

# %%
os.chdir('c:/data/exam_sqc')
os.getcwd()
# Out:
# 'c:\\data\\exam_sqc'

# %%
# anaconda3 경로 확인

import sys
print(sys.executable)
# Out:
# C:\Users\user\anaconda3\python.exe

# %%
food1 = pd.read_csv('food_clean.csv')
food1.head()
# Out:
#   Lot_ID Line Operator  Temp  Humidity  Weight  Defect
# 0   L003    A       O8  26.4      42.9   99.92       0
# 1   L029    B       O2  24.3      57.7  101.77       0
# 2   L035    A       O4  23.5      44.3   99.82       0
# 3   L039    C       O3  24.4      38.2  100.60       0
# 4   L018    A       O9  26.5      44.4   99.76       0

# %%
# 관리도를 그리기 위한 함수를 호출

from xbar_r_chart import plot_xbar_r_chart # xbar-r 관리도 그리기 위한 목적
import nelson_rules # nelson rule 적용을 위한 목적

# %%
# 예제 데이터 호출
food1 = pd.read_csv('food_clean.csv')
food1.head()
# Out:
#   Lot_ID Line Operator  Temp  Humidity  Weight  Defect
# 0   L003    A       O8  26.4      42.9   99.92       0
# 1   L029    B       O2  24.3      57.7  101.77       0
# 2   L035    A       O4  23.5      44.3   99.82       0
# 3   L039    C       O3  24.4      38.2  100.60       0
# 4   L018    A       O9  26.5      44.4   99.76       0

# %%
# 부분군 설정
# 부분군 형성을 위해서 index 사용 + index 번호를 1부터 시작하기 위함
food1["Group"] = food1.index // 5 + 1
food1
# Out:
#     Lot_ID Line Operator  Temp  Humidity  Weight  Defect  Group
# 0     L003    A       O8  26.4      42.9   99.92       0      1
# 1     L029    B       O2  24.3      57.7  101.77       0      1
# 2     L035    A       O4  23.5      44.3   99.82       0      1
# 3     L039    C       O3  24.4      38.2  100.60       0      1
# 4     L018    A       O9  26.5      44.4   99.76       0      1
# ..     ...  ...      ...   ...       ...     ...     ...    ...
# 410   L046    A       O2  23.1      58.1  100.69       0     83
# 411   L013    A       O9  25.5      53.0   99.55       0     83
# 412   L027    A       O5  24.2      46.3  100.86       0     83
# 413   L047    C       O5  24.0      50.7   98.69       0     83
# 414   L040    A       O4  23.1      50.7  100.65       0     83
#
# [415 rows x 8 columns]

# %%
# xbar-r 관리도 그리기
plot_xbar_r_chart(food1, subgroup_size = 5, value_col = "Temp", nelson_rules = 'all')
plt.show()

# %%
# xbar-r 관리도 그리기
plot_xbar_r_chart(food1, subgroup_size = 5, value_col = "Weight", nelson_rules = 'all')
plt.show()

# %%
# xbar-r 관리도 그리기
plot_xbar_r_chart(food1, subgroup_size = 5, value_col = "Humidity", nelson_rules = 'all')
plt.show()

# %%
# I-MR 관리도를 그리기 위한 함수 모듈 호출
from i_mr_chart import plot_imr_chart # I-MR 관리돌르 그리기 위한 함수 호출

# %%
weight = pd.read_csv('food_clean.csv')
weight.head()
# Out:
#   Lot_ID Line Operator  Temp  Humidity  Weight  Defect
# 0   L003    A       O8  26.4      42.9   99.92       0
# 1   L029    B       O2  24.3      57.7  101.77       0
# 2   L035    A       O4  23.5      44.3   99.82       0
# 3   L039    C       O3  24.4      38.2  100.60       0
# 4   L018    A       O9  26.5      44.4   99.76       0

# %%
plot_imr_chart(weight, value_col = 'Weight', mr_span = 2)
plt.show()
